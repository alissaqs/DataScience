# %% [markdown]
# <a href="https://colab.research.google.com/github/alissaqs/DataScience/blob/main/Linear_Regression_Project_China_Inequality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel('data.xlsx')

# %%
data
# Out:
#     Year  Literacy adult (15+) rate (%)   Gini Index (%)  \
# 0   1980                             NaN             NaN
# 1   1981                             NaN             NaN
# 2   1982                           65.50             NaN
# 3   1983                             NaN             NaN
# 4   1984                             NaN             NaN
# 5   1985                             NaN             NaN
# 6   1986                             NaN             NaN
# 7   1987                             NaN             NaN
# 8   1988                             NaN             NaN
# 9   1989                             NaN             NaN
# 10  1990                           77.79            32.2
# 11  1991                             NaN             NaN
# 12  1992                             NaN             NaN
# 13  1993                             NaN             NaN
# 14  1994                             NaN             NaN
# ...

# %%
data.describe().round(2)
# Out:
#           Year  Literacy adult (15+) rate (%)   Gini Index (%)  \
# count    41.00                            5.00           10.00
# mean   2000.00                           85.23           39.47
# std      11.98                           13.32            3.64
# min    1980.00                           65.50           32.20
# 25%    1990.00                           77.79           38.52
# 50%    2000.00                           90.92           39.45
# 75%    2010.00                           95.12           42.35
# max    2020.00                           96.84           43.70
#
#        Urbanization Rate (%)  Urban Monthly mean (PPP$)   \
# count                  41.00                       17.00
# mean                   38.03                      229.21
# std                    13.10                      137.73
# min                    19.35                       56.34
# 25%                    26.44                       99.26
# ...

# %%
data.corr().round(4)
# Out:
#                                   Year  Literacy adult (15+) rate (%)   \
# Year                            1.0000                          0.9506
# Literacy adult (15+) rate (%)   0.9506                          1.0000
# Gini Index (%)                  0.6939                          1.0000
# Urbanization Rate (%)           0.9935                          0.9101
# Urban Monthly mean (PPP$)       0.9582                          1.0000
# Rural Monthly mean (PPP$)       0.9158                          1.0000
#
#                                 Gini Index (%)  Urbanization Rate (%)  \
# Year                                    0.6939                 0.9935
# Literacy adult (15+) rate (%)           1.0000                 0.9101
# Gini Index (%)                          1.0000                 0.6785
# Urbanization Rate (%)                   0.6785                 1.0000
# Urban Monthly mean (PPP$)               0.5596                 0.9814
# ...

# %%
fig, ax = plt.subplots(figsize=(20,6))

ax.set_title('Urbanization Rate (%)', fontsize=20)
ax.set_ylabel('Rate', fontsize=16)
ax.set_xlabel('Years (1980 - 2020)', fontsize=16)
ax = data['Urbanization Rate (%)'].plot(fontsize=14)

# %%
ax = sns.boxplot(data=data['Urbanization Rate (%)'], orient='v', width=0.2)
ax.figure.set_size_inches(12, 6)
ax.set_title('Urbanization Rate', fontsize=20)
ax.set_ylabel('Rate', fontsize=16)
ax

# %%
ax = sns.boxplot(data=data['Gini Index (%)'], orient='v', width=0.2)
ax.figure.set_size_inches(12, 6)
ax.set_title('Gini Index', fontsize=20)
ax.set_ylabel('Index', fontsize=16)
ax

# %%
ax = sns.distplot(data['Urbanization Rate (%)'])
ax.figure.set_size_inches(12, 6)
ax.set_title('Frequency Distribution', fontsize=20)
ax.set_ylabel('Rate', fontsize=16)
ax
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.distplot(data['Gini Index (%)'])
ax.figure.set_size_inches(12, 6)
ax.set_title('Frequency Distribution', fontsize=20)
ax.set_ylabel('Index', fontsize=16)
ax
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
ax = sns.pairplot(data)

# %%
ax = sns.lmplot(x="Gini Index (%)", y="Urbanization Rate (%)", data=data)
ax.fig.suptitle('Frequencies Distribution', fontsize=16, y=1.02)
ax.set_xlabels("Gini Index (%)", fontsize=14)
ax.set_ylabels("Urbanization Rate (%)", fontsize=14)
ax

# %%
data = data.fillna(0)
data
# Out:
#     Year  Literacy adult (15+) rate (%)   Gini Index (%)  \
# 0   1980                            0.00             0.0
# 1   1981                            0.00             0.0
# 2   1982                           65.50             0.0
# 3   1983                            0.00             0.0
# 4   1984                            0.00             0.0
# 5   1985                            0.00             0.0
# 6   1986                            0.00             0.0
# 7   1987                            0.00             0.0
# 8   1988                            0.00             0.0
# 9   1989                            0.00             0.0
# 10  1990                           77.79            32.2
# 11  1991                            0.00             0.0
# 12  1992                            0.00             0.0
# 13  1993                            0.00             0.0
# 14  1994                            0.00             0.0
# ...

# %%
from sklearn.model_selection import train_test_split
y = data['Urbanization Rate (%)']
X = data[['Gini Index (%)', 'Year']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2811)

# %%
X_train.shape
# Out:
# (28, 2)

# %%
X_train.shape[0] + X_test.shape[0]
# Out:
# 41

# %%
X.shape[0] * 0.3
# Out:
# 12.299999999999999

# %%
X.shape[0] * 0.7
# Out:
# 28.7

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('R² = {}'.format(model.score(X_train, y_train).round(2)))
# Out:
# R² = 0.99

# %%
y_predicted = model.predict(X_test)

# %%
print('R² = %s' % metrics.r2_score(y_test, y_predicted).round(2))
# Out:
# R² = 0.98

# %%
model.predict(input)[0]
# Out:
# 35.38522983282928

# %%
model.intercept_
# Out:
# -2185.4921676124413

# %%
model.coef_
# Out:
# array([0.01222224, 1.11155025])

# %%
X.columns
# Out:
# Index(['Gini Index (%)', 'Year'], dtype='object')

# %%
index=['Intercept','Gini Index', 'Year']

# %%
pd.DataFrame(data=np.append(model.intercept_, model.coef_), index=index, columns=['Parameters'])
# Out:
#              Parameters
# Intercept  -2185.492168
# Gini Index     0.012222
# Year           1.111550
